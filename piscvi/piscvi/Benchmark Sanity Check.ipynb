# %% [markdown]
# ## Benchmark Sanity Check

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import os
import time

# %%
data_path = "/cluster/work/bewi/data/tahoe100/h5ad/gdsc_controls_processed_fcr.h5ad"
print(f"Loading AnnData from {data_path} at", time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()), flush=True)
adata = sc.read(data_path)
# Out:
# Loading AnnData from /cluster/work/bewi/data/tahoe100/h5ad/gdsc_controls_processed_fcr.h5ad at 2026-01-12 19:38:41

# %%
adata.obs
# Out:
#                        sample  gene_count  tscp_count  mread_count  \
# BARCODE_SUB_LIB_ID
# 96_084_134-lib_1235  smp_1974        1349        1909         2273
# 96_140_170-lib_1847  smp_2550        1428        2237         2653
# 95_079_074-lib_2339  smp_1685         716         965         1140
# 96_098_104-lib_1290  smp_1974        1192        1645         1936
# 95_043_104-lib_1337  smp_2069        6035       15656        18180
# ...                       ...         ...         ...          ...
# 96_018_063-lib_1749  smp_2454        1628        2643         3124
# 96_034_059-lib_2072  smp_2838         856        1126         1334
# 96_168_010-lib_2336  smp_1686        2583        4785         5731
# 96_105_188-lib_893   smp_1590        1841        2783         3423
# 95_053_056-lib_2153  smp_2837         724        1070         1264
#
#                             drugname_drugconc     drug  cell_line sublibrary  \
# BARCODE_SUB_LIB_ID
# ...

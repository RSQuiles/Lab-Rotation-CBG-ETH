# %% [markdown]
# # Compare Predictions using Latent Features vs Raw Data

# %%
import importlib
import fcr.validation as validation

importlib.reload(validation)
from fcr.validation import compare_latent_vs_raw_predictions

# %% [markdown]
# ### Test 1

# %% [markdown]
# Random Forest:

# %%
model_dir = "/cluster/work/bewi/members/rquiles/experiments/error_screening/3_cell_2_drug_kl+"
compare_latent_vs_raw_predictions(model_dir, "cell_name", classifier="random_forest")
# Out:
# Loading model from: /cluster/work/bewi/members/rquiles/experiments/error_screening/3_cell_2_drug_kl+
# Target feature: cell_name
# Performing automatic train-test split with 0.2 ratio.
# Loading AnnData from: /cluster/work/bewi/members/rquiles/experiments/datasets/3_cells_2_drugs.h5ad
# Computing latents for 43301 samples...
# Computing latent representations...
# ZX mean: 0.15005797 ZX std: 0.82456356
# ZXT mean: 0.16008034 ZXT std: 0.8140079
# ZT mean: 0.15055294 ZT std: 0.8265902
# Latent dimensions - ZX: 64, ZXT: 64, ZT: 64
# Total latent dimension: 192
#
# Training random_forest classifiers...
#
# Raw Data Results:
#   Accuracy: 0.9843
#   F1 (macro): 0.9738
#   F1 (weighted): 0.9842
#
# Combined Latents Results:
#   Accuracy: 0.7690
#   F1 (macro): 0.5723
#   F1 (weighted): 0.7258
#
# ZX Latents Results:
#   Accuracy: 0.7103
#   F1 (macro): 0.4967
#   F1 (weighted): 0.6579
#
# ZXT Latents Results:
#   Accuracy: 0.7355
#   F1 (macro): 0.5091
#   F1 (weighted): 0.6843
#
# ...

# %% [markdown]
# ### Test 2:

# %%
model_dir = "/cluster/work/bewi/members/rquiles/experiments/error_screening/3_cell_2_drug_lr-"
compare_latent_vs_raw_predictions(model_dir, "cell_name", classifier="random_forest", target_epoch=500)
# Out:
# Loading model from: /cluster/work/bewi/members/rquiles/experiments/error_screening/3_cell_2_drug_lr-
# Target feature: cell_name
# Performing automatic train-test split with 0.2 ratio.
# Loading AnnData from: /cluster/work/bewi/members/rquiles/experiments/datasets/3_cells_2_drugs.h5ad
# Computing latents for 43301 samples...
# Computing latent representations...
# ZX mean: 0.14913608 ZX std: 0.8473822
# ZXT mean: 0.14754833 ZXT std: 0.816595
# ZT mean: 0.17074576 ZT std: 0.8260201
# Latent dimensions - ZX: 64, ZXT: 64, ZT: 64
# Total latent dimension: 192
#
# Training random_forest classifiers...
#
# Raw Data Results:
#   Accuracy: 0.9843
#   F1 (macro): 0.9738
#   F1 (weighted): 0.9842
#
# Combined Latents Results:
#   Accuracy: 0.8508
#   F1 (macro): 0.7438
#   F1 (weighted): 0.8340
#
# ZX Latents Results:
#   Accuracy: 0.7919
#   F1 (macro): 0.6863
#   F1 (weighted): 0.7742
#
# ZXT Latents Results:
#   Accuracy: 0.7736
#   F1 (macro): 0.6361
#   F1 (weighted): 0.7481
#
# ...

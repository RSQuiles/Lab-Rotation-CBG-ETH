# %% [markdown]
# # Plot UMAP Progression During Training

# %%
from fcr.validation.view_results import plot_progression

# %%
model_dir = "/cluster/work/bewi/members/rquiles/experiments/error_screening/3_cell_2_drug_permut_mod_lat-_kl+"
plot_progression(model_dir, "ZXs", "cell_name", freq=100)
# Out:
# Performing automatic train-test split with 0.2 ratio.
# Plotting UMAP before FCR...
# Performing automatic train-test split with 0.2 ratio.
# Computing latent representations...
# ZX mean: 0.17881605 ZX std: 0.81161267
# ZXT mean: 0.18675408 ZXT std: 0.8290291
# ZT mean: 0.14054321 ZT std: 0.84476537
# Performing automatic train-test split with 0.2 ratio.
# Computing latent representations...
# ZX mean: 0.18029179 ZX std: 0.81216973
# ZXT mean: 0.18559243 ZXT std: 0.82866883
# ZT mean: 0.1382276 ZT std: 0.8421468
# Performing automatic train-test split with 0.2 ratio.
# Computing latent representations...
# ZX mean: 0.18144149 ZX std: 0.8135314
# ZXT mean: 0.1860624 ZXT std: 0.82977176
# ZT mean: 0.13812535 ZT std: 0.8415255
# Performing automatic train-test split with 0.2 ratio.
# Computing latent representations...
# ZX mean: 0.17999348 ZX std: 0.81321114
# ZXT mean: 0.1862939 ZXT std: 0.8283115
# ZT mean: 0.13884477 ZT std: 0.84141564
# ...

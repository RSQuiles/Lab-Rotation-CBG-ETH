# %%
import scanpy as sc
import pandas as pd
import numpy as np
from scipy import sparse
import re
import os
from pubchempy import get_compounds
import time

# %%
base_dir = "/cluster/work/bewi/members/rquiles/zeroshot_amr/data"

# %% [markdown]
# ### Metadata file

# %%
metadata = pd.read_csv(os.path.join(base_dir, "combined_long_table.csv"))

# %%
metadata
# Out:
#          species            sample_id         drug  response dataset
# 0          HOP62  95_001_111-lib_1681  Doxorubicin       1.0     any
# 1          HOP62  95_001_111-lib_1681  Doxorubicin       1.0     any
# 2          HOP62  95_001_111-lib_1681    Etoposide       1.0     any
# 3          HOP62  95_001_111-lib_1681  Gemcitabine       1.0     any
# 4          HOP62  95_001_111-lib_1681  Gemcitabine       1.0     any
# ...          ...                  ...          ...       ...     ...
# 51895436    HT29  96_192_081-lib_2608   Nelarabine       0.0     any
# 51895437    HT29  96_192_081-lib_2608  Vincristine       0.0     any
# 51895438    HT29  96_192_081-lib_2608   Venetoclax       0.0     any
# 51895439    HT29  96_192_081-lib_2608  Osimertinib       0.0     any
# 51895440    HT29  96_192_081-lib_2608  Vinorelbine       1.0     any
#
# [51895441 rows x 5 columns]

# %%
unique_lines = np.array(metadata["species"].unique())
unique_drugs = np.array(metadata["drug"].unique())

# %%
print(f"Number unique lines: {len(unique_lines)}")
print(f"Unique lines: {unique_lines}")
print(f"Number unique drugs: {len(unique_drugs)}")
print(f"Unique drugs: {unique_drugs}")
# Out:
# Number unique lines: 46
# Unique lines: ['HOP62' 'A172' 'NCIH2030' 'NCISNU1' 'HCT15' 'A498' 'ASPC1' 'MIAPACA2'
#  'HT29' 'SW900' 'COLO205' 'CFPAC1' 'LOXIMVI' 'LS180' 'RKO' 'J82' 'C33A'
#  'NCIH1792' 'C32' 'LOVO' 'NCIH2347' 'RPMI7951' 'A549' 'NCIH23' 'SKMEL2'
#  'AN3CA' 'HS578T' 'KATOIII' 'SNU423' 'HEC1A' 'BT474' 'A427' 'SHP77'
#  'CHP212' 'HS766T' 'C3A' 'SW1417' 'SW48' 'PANC0327' 'NCIH1573' 'H4'
#  'SW1088' 'NCIH596' 'NCIH661' 'SW1271' 'NCIH2122']
# Number unique drugs: 65
# Unique drugs: ['Doxorubicin' 'Etoposide' 'Gemcitabine' 'Mitomycin-C' 'Vinorelbine'
#  'Bicalutamide' 'Ponatinib' '5-Fluorouracil' 'Bexarotene' 'Bleomycin'
#  'Pazopanib' 'Ruxolitinib' 'Idelalisib' 'Cabozantinib' 'Belinostat'
#  'Alectinib' 'Pemetrexed' 'Panobinostat' 'Vinblastine' 'Cisplatin'
#  'Cytarabine' 'Docetaxel' 'Methotrexate' 'Tretinoin' 'Gefitinib'
#  'Vorinostat' 'Nilotinib' 'Temsirolimus' 'Olaparib' 'Bosutinib'
#  'Lenalidomide' 'Axitinib' 'Afatinib' 'Vismodegib' 'Palbociclib'
#  'Rucaparib' 'Tamoxifen' 'Trametinib' 'Dabrafenib' 'Temozolomide'
#  'Fulvestrant' 'SN-38' 'Irinotecan' 'Oxaliplatin' 'Epirubicin'
#  'Cyclophosphamide' 'Ibrutinib' 'Zoledronate' 'Carmustine' 'Topotecan'
#  'Teniposide' 'Mitoxantrone' 'Dactinomycin' 'Nelarabine' 'Vincristine'
#  'Venetoclax' 'Osimertinib' 'Dasatinib' 'Paclitaxel' 'Crizotinib'
#  'Rapamycin' 'Sorafenib' 'Erlotinib' 'Bortezomib' 'Lapatinib']

# %%
# Determine zeroshot subsets
train_lines = unique_lines[:35]
seen_lines = unique_lines[35:40]
zeroshot_lines = unique_lines[40:]
print(f"Zeroshot cell lines: {zeroshot_lines}")

zeroshot_drugs = ['Erlotinib', 'Rapamycin', 'Sunitinib', 'Paclitaxel', 'Sorafenib', 'Imatinib', 'Crizotinib', 'Dasatinib', 'Bortezomib', 'Lapatinib']
print(f"Zeroshot drugs: {zeroshot_drugs}")
# Out:
# Zeroshot cell lines: ['H4' 'SW1088' 'NCIH596' 'NCIH661' 'SW1271' 'NCIH2122']
# Zeroshot drugs: ['Erlotinib', 'Rapamycin', 'Sunitinib', 'Paclitaxel', 'Sorafenib', 'Imatinib', 'Crizotinib', 'Dasatinib', 'Bortezomib', 'Lapatinib']

# %%
# Test if all zeroshot drugs have been removed from training set
print("All Zeroshot Drugs have been removed from training set!")
metadata[(metadata["species"].isin(train_lines)) & (metadata["drug"].isin(zeroshot_drugs))]
# Out:
# All Zeroshot Drugs have been removed from training set!
# Empty DataFrame
# Columns: [species, sample_id, drug, response, dataset]
# Index: []

# %% [markdown]
# ### Data Split File

# %%
splits = pd.read_csv(os.path.join(base_dir, "data_splits.csv"))

# %%
# Ensure train lines are only in train set
print("train_lines are only in train set!")
splits[splits["species"].isin(train_lines)]["Set"].unique()
# Out:
# train_lines are only in train set!
# array(['train'], dtype=object)

# %%
# Ensure zeroshot lines are only in test set
print("zeroshot_lines are only in test set!")
splits[splits["species"].isin(zeroshot_lines)]["Set"].unique()
# Out:
# zeroshot_lines are only in test set!
# array(['test'], dtype=object)

# %%
# Ensure "seen" lines are present in train and test at the adequate ratio
print("seen_lines:")
print(f"Sets: {splits[splits['species'].isin(seen_lines)]['Set'].unique()}")
# splits[(splits['species'].isin(seen_lines) & splits['Set'] == 'test')]
len(splits[(splits['species'].isin(seen_lines)) & (splits['Set'] == 'test')]) / len(splits[(splits['species'].isin(seen_lines))])
# Out:
# seen_lines:
# Sets: ['test' 'train']
# 0.20004186801109503

# %% [markdown]
# ## Original controls file

# %%
data_path = "/cluster/work/bewi/data/tahoe100/h5ad/controls_merged.h5ad"
adata = sc.read_h5ad(data_path)

# %% [markdown]
# ## Drug Fingerprints

# %%
fps = pd.read_csv(os.path.join(base_dir, "drug_fingerprints_Mol_selfies.csv"))

# %%
fps["drug"].unique()
# Out:
# array(['Talc', 'Bortezomib', 'Ixazomib', 'Ixazomib citrate',
#        'Lactate (calcium)', 'Bisoprolol (hemifumarate)', 'Fumaric acid',
#        'Hydroxyurea', 'L-Eflornithine (monohydrochloride)',
#        'Cysteamine (hydrochloride)', 'Darinaparsin',
#        'Entecavir (monohydrate)', 'Allantoin', '5-Fluorouracil',
#        'L-Thyroxine (sodium salt pentahydrate)', 'Gallic acid',
#        'Gallic acid (hydrate)', 'ERK5-IN-2', 'Vilanterol',
#        'Niclosamide (olamine)', 'Norepinephrine (hydrochloride)',
#        'Triclosan', 'Mitoxantrone (dihydrochloride)',
#        'Pentamidine (isethionate)', 'Folic acid',
#        'Balsalazide (sodium hydrate)', 'Resveratrol', 'PF-06260933',
#        'Daidzin', 'Pemetrexed', 'Econazole', 'XRK3F2', 'Arbutin',
#        'Tucidinostat', 'Pexidartinib (hydrochloride)',
#        'Sodium Salicylate', 'Salicylic acid', 'Ataluren', '4EGI-1',
#        'Clotrimazole', 'Phenytoin (sodium)', 'SBI-0640756', 'Oxaprozin',
#        'Baicalin', 'Belinostat', 'Carbamazepine', 'HI-TOPK-032',
#        '8-Hydroxyquinoline', 'Riluzole hydrochloride', 'Minodronic acid',
#        'GSK1059615', 'Gemcitabine', 'Cytarabine',
#        'Cytarabine (hydrochloride)', 'Uridine', 'Selinexor', 'Furosemide',
#        'Adenosine', '5-Azacytidine', 'Clofarabine', 'Adenine',
#        'Allopurinol', 'Trifluridine', 'Brivudine', 'Idoxuridine',
#        'Decitabine', 'Lenalidomide (hemihydrate)', 'DT-061', 'BAY1125976',
#        'Larotrectinib', 'Larotrectinib sulfate', 'olaparib', 'Filgotinib',
#        'ULK-101', 'Oxaliplatin', 'Cilostazol', 'LY2090314', 'Cobimetinib',
#        'Asciminib', 'Capivasertib', 'Penfluridol', 'Lonafarnib',
#        'Pimozide', 'Clonidine (hydrochloride)', 'Brimonidine', 'AT7519',
#        'Hydroxyfasudil', 'BI-78D3', 'ETC-206', 'LJI308', 'Bimiralisib',
#        'Bentamapimod', 'Lipoic acid', 'Peretinoin', 'IQ 1',
#        'Acetohexamide', 'Pentoxifylline', 'DTP3', 'Acetazolamide',
#        'Pasireotide (acetate)', 'Chlorhexidine (diacetate)', 'Aspirin',
#        'Abiraterone acetate', 'Sivelestat (sodium tetrahydrate)',
#        'Atazanavir (sulfate)', 'Terfenadine', 'Bosentan (hydrate)',
#        'Dabrafenib', 'Ralimetinib dimesylate', 'Saquinavir',
#        'Pentagastrin', 'Anastrozole', 'Harringtonine',
#        'Homoharringtonine', 'Flutamide', 'Thymopentin', 'Aliskiren',
#        'Verapamil', '(R)-Verapamil (hydrochloride)', 'Ritonavir',
#        'Goserelin (acetate)', 'Bestatin', 'Bestatin (hydrochloride)',
#        'Imiquimod (maleate)', 'Imiquimod (hydrochloride)', 'Encorafenib',
#        'AZD1390', 'Sapanisertib', 'Torkinib', 'Belumosudil',
#        'Belumosudil (mesylate)', 'Esmolol (hydrochloride)', 'Erdafitinib',
#        'Malotilate', 'Fenofibrate', 'MK-8353', 'crizotinib',
#        '(S)-Crizotinib', 'Crizotinib (hydrochloride)', 'Aprepitant',
#        'Cinacalcet', 'Naproxen', 'Zileuton', 'Voriconazole',
#        'Carbidopa (monohydrate)', 'Silodosin', 'Darolutamide',
#        'Benproperine (phosphate)', 'Bicalutamide', 'Captopril',
#        'Tirabrutinib', 'Tirabrutinib (hydrochloride)', 'Mifepristone',
#        'Fostamatinib (disodium hexahydrate)', 'Temuterkib',
#        'Tetracycline (hydrochloride)', 'Glycyrrhizic acid',
#        'Diammonium Glycyrrhizinate', 'venetoclax', 'Delamanid',
#        'Dexmedetomidine', 'Ranolazine', 'Lopinavir', 'Valdecoxib',
#        'Cloxacillin (sodium)', 'Elagolix sodium', 'palbociclib',
#        'Retinoic acid', 'PH-797804', 'Ponatinib', 'Radotinib',
#        'NVP-BHG712', 'Canagliflozin', 'MK-3903', 'EX229',
#        'Flumatinib (mesylate)', 'Tucatinib', 'Trimetrexate', 'APTO-253',
#        'Vitamin K4', 'Panobinostat', 'Rimonabant',
#        'Rimonabant (Hydrochloride)', 'Ligustrazine', 'Sulfisoxazole',
#        'Alpelisib', 'Trametinib', 'Nevirapine', 'Tomivosertib',
#        'Paclitaxel', 'Docetaxel', 'Docetaxel (Trihydrate)', 'Roxadustat',
#        'Thymol', 'Gemfibrozil', 'Vortioxetine', 'OTS514', 'Pralsetinib',
#        'Menadione', 'Ciclopirox', 'Methylthiouracil', 'Tolcapone',
#        'Tolmetin', 'Celecoxib',
#        'S-Adenosyl-L-methionine (disulfate tosylate)',
#        'Lapatinib ditosylate', 'LY-2584702 (tosylate salt)',
#        'Edoxaban (tosylate monohydrate)', 'Lumateperone (tosylate)',
#        'Mozavaptan', 'Bexarotene', 'Sulfatinib', 'Olanzapine', 'AZD-7648',
#        'Megestrol', 'Omeprazole (sodium)', 'Omeprazole',
#        'Fedratinib (hydrochloride hydrate)', 'Meloxicam', 'Pyridoxine',
#        'Pyridoxine (hydrochloride)', 'Ornidazole', 'Raltitrexed',
#        'BI-3406', 'Triamcinolone', 'Drospirenone', 'Eplerenone',
#        'Quinestrol', 'Estrone sulfate (potassium)', 'Finasteride',
#        'Fulvestrant', 'Monocrotaline', 'Ouabain (Octahydrate)',
#        'Rutin (trihydrate)', 'Hesperidin', 'Digitoxin',
#        'Doxorubicin (hydrochloride)', 'Epirubicin (hydrochloride)',
#        'Idarubicin (hydrochloride)', 'Plicamycin', 'Rifaximin',
#        'Doxycycline (monohydrate)', 'Fusidic acid', 'Ipatasertib',
#        'Medroxyprogesterone acetate', 'Methylprednisolone succinate',
#        'Dexamethasone', 'Dihydroartemisinin', 'Artesunate', 'Artemether',
#        'Rapamycin', 'Temsirolimus', 'Everolimus', 'Tofacitinib',
#        'Tofacitinib (citrate)', 'Sonidegib', 'AZD-8055',
#        'Elimusertib hydrochloride', 'Clobetasol propionate',
#        'Betamethasone dipropionate', 'Posaconazole',
#        'Pravastatin (sodium)', 'Ivermectin', 'Topotecan (hydrochloride)',
#        'Vinblastine (sulfate)', 'vincristine', 'Indacaterol (maleate)',
#        'Pimitespib', 'Irinotecan', 'Irinotecan (hydrochloride)',
#        'Dinaciclib', 'Pioglitazone', 'Volasertib', 'Cyclosporin A',
#        'Erythromycin', 'Azithromycin (hydrate)', 'Perindopril (erbumine)',
#        'Sildenafil', 'Budesonide', 'Hexylresorcinol', 'Oleic acid',
#        'Fingolimod (hydrochloride)', 'Daptomycin', 'Orlistat',
#        'Levobupivacaine (hydrochloride)', 'Proglumide',
#        'Ropivacaine (hydrochloride monohydrate)', 'Macitentan',
#        'Vemurafenib', 'Lidocaine (hydrochloride)', 'Sunitinib',
#        'Procainamide (hydrochloride)', 'Lucanthone', 'RMC-6236',
#        'Pemigatinib', 'Infigratinib', 'NG25', 'Abemaciclib',
#        'Bimatoprost', 'Dorzolamide (hydrochloride)', 'Tazarotene',
#        'Neratinib', 'Neratinib (maleate)', 'Dapagliflozin',
#        'Dapagliflozin ((2S)-1,2-propanediol, hydrate)', 'Auranofin',
#        'TAK-901', 'Loperamide (hydrochloride)', 'Ribociclib',
#        'Altretamine', 'Demeclocycline', 'Afatinib', 'Relugolix',
#        'Citalopram (hydrobromide)', 'Almonertinib (hydrochloride)',
#        'Almonertinib (mesylate)', 'Diphenhydramine', 'ML264',
#        'Methotrexate', 'Ivabradine (hydrochloride)', 'Rosiglitazone',
#        'Piroxicam', 'c-Kit-IN-1', 'CP21R7', '9-ING-41', 'Binimetinib',
#        'TAK-733', 'Bendamustine', 'Benztropine (mesylate)', 'Tadalafil',
#        'Vandetanib', 'Glasdegib', 'Isocorydine', 'Berbamine',
#        'Berbamine (dihydrochloride)', 'Cepharanthine', 'Sinomenine',
#        'Adagrasib', 'LB-100', 'Entrectinib', 'AZD2858', 'Capmatinib',
#        'Apalutamide', 'Regorafenib', 'Phenylephrine (hydrochloride)',
#        'Rucaparib (phosphate)', 'Clopidogrel', 'Dimethyl fumarate',
#        'Methyl aminolevulinate (hydrochloride)', 'Mebendazole',
#        'Tranilast', 'Gefitinib', 'Simotinib', 'Bergenin', 'Ferulic acid',
#        'Amsacrine', 'Palmatine (chloride)',
#        'Berberine (chloride hydrate)', 'Futibatinib',
#        'Tubulin inhibitor 6', 'Anethole trithione',
#        'Cabozantinib (S-malate)', 'Fluvoxamine', 'Fluvoxamine (maleate)',
#        'Erlotinib', 'Belzutifan', 'Vismodegib', 'Nimesulide',
#        'Nafamostat (mesylate)', 'Busulfan', '18β-Glycyrrhetinic acid',
#        'Trametinib (DMSO_TF solvate)', 'Sacubitril/Valsartan',
#        'Pitavastatin (Calcium)', 'Verteporfin',
#        'Quinidine (15% dihydroquinidine)', 'Canagliflozin (hemihydrate)',
#        'Osimertinib (mesylate)', 'γ-Oryzanol', 'DMSO_TF'], dtype=object)

# %%
# Normalize drug names for the 2 sets
def norm_drug(s):
    """Normalize drug names for matching."""
    if s is None:
        return None
    s = s.lower()
    
    # Remove GDSC suffix ___123
    s = re.sub(r"___\d+", "", s)

    # Remove parentheses content (e.g., (hydrochloride))
    s = re.sub(r"\([^)]*\)", "", s)

    # Remove salts / hydrate words
    remove_words = [
        "hydrochloride", "monohydrochloride", "dihydrochloride",
        "sodium", "hydrate", "monohydrate", "pentahydrate",
        "hemifumarate", "citrate", "acid", "salt"
    ]
    for w in remove_words:
        s = s.replace(w, "")

    # Remove punctuation
    s = re.sub(r"[^a-z0-9]+", "", s)

    return s.strip()

# %%
tahoe_drugs = fps["drug"].unique()
gdsc_drugs = np.array(metadata["drug"].unique())

# %%
for t_drug in tahoe_drugs:
    if "Etoposide" in t_drug:
        print(drug)

# %%
# Build mapping from GDSC → Tahoe using normalized names.
norm_tahoe = {norm_drug(d): d for d in tahoe_drugs}

mapping = {}
for d in gdsc_drugs:
    key = norm_drug(d)
    mapping[d] = norm_tahoe.get(key, None)

mapping
# Out:
# {'Doxorubicin___133': 'Doxorubicin (hydrochloride)',
#  'Doxorubicin___1386': 'Doxorubicin (hydrochloride)',
#  'Etoposide': None,
#  'Gemcitabine___135': 'Gemcitabine',
#  'Gemcitabine___1393': 'Gemcitabine',
#  'Mitomycin-C': None,
#  'Vinorelbine': None,
#  'Bicalutamide___150': 'Bicalutamide',
#  'Bicalutamide___1502': 'Bicalutamide',
#  'Ponatinib': 'Ponatinib',
#  '5-Fluorouracil': '5-Fluorouracil',
#  'Bexarotene': 'Bexarotene',
#  'Bleomycin': None,
#  'Pazopanib': None,
#  'Ruxolitinib': None,
#  'Idelalisib': None,
#  'Cabozantinib': 'Cabozantinib (S-malate)',
#  'Belinostat': 'Belinostat',
#  'Alectinib': None,
#  'Pemetrexed': 'Pemetrexed',
#  'Panobinostat': 'Panobinostat',
#  'Vinblastine': 'Vinblastine (sulfate)',
#  'Cisplatin___1005': None,
#  'Cisplatin___1496': None,
#  'Cytarabine': 'Cytarabine (hydrochloride)',
#  'Docetaxel': 'Docetaxel (Trihydrate)',
#  'Methotrexate': 'Methotrexate',
#  'Tretinoin': None,
#  'Gefitinib': 'Gefitinib',
#  'Vorinostat': None,
#  'Nilotinib': None,
#  'Temsirolimus': 'Temsirolimus',
#  'Olaparib___1017': 'olaparib',
#  'Olaparib___1495': 'olaparib',
#  'Bosutinib': None,
#  'Lenalidomide': 'Lenalidomide (hemihydrate)',
#  'Axitinib': None,
#  'Afatinib___1032': 'Afatinib',
#  'Afatinib___1377': 'Afatinib',
#  'Vismodegib': 'Vismodegib',
#  'Palbociclib': 'palbociclib',
#  'Cetuximab': None,
#  'Rucaparib': 'Rucaparib (phosphate)',
#  'Tamoxifen': None,
#  'Trametinib': 'Trametinib (DMSO_TF solvate)',
#  'Dabrafenib': 'Dabrafenib',
#  'Temozolomide': None,
#  'Fulvestrant': 'Fulvestrant',
#  'SN-38___1490': None,
#  'SN-38___1494': None,
#  'Cisplatin': None,
#  'Docetaxel___1007': 'Docetaxel (Trihydrate)',
#  'Docetaxel___1819': 'Docetaxel (Trihydrate)',
#  'Olaparib': 'olaparib',
#  'Afatinib': 'Afatinib',
#  'Irinotecan': 'Irinotecan (hydrochloride)',
#  'Oxaliplatin___1089': 'Oxaliplatin',
#  'Oxaliplatin___1806': 'Oxaliplatin',
#  'Gemcitabine': 'Gemcitabine',
#  'Fulvestrant___1200': 'Fulvestrant',
#  'Fulvestrant___1816': 'Fulvestrant',
#  'Epirubicin': 'Epirubicin (hydrochloride)',
#  'Cyclophosphamide': None,
#  'Ibrutinib': None,
#  'Zoledronate': None,
#  'Carmustine': None,
#  'Topotecan': 'Topotecan (hydrochloride)',
#  'Teniposide': None,
#  'Mitoxantrone': 'Mitoxantrone (dihydrochloride)',
#  'Dactinomycin___1811': None,
#  'Dactinomycin___1911': None,
#  'Nelarabine': None,
#  'Vincristine': 'vincristine',
#  'Venetoclax': 'venetoclax',
#  'Osimertinib': 'Osimertinib (mesylate)',
#  'Dasatinib': None,
#  'Paclitaxel': 'Paclitaxel',
#  'Crizotinib': 'Crizotinib (hydrochloride)',
#  'Rapamycin': 'Rapamycin',
#  'Sorafenib': None,
#  'Erlotinib': 'Erlotinib',
#  'Bortezomib': 'Bortezomib',
#  'Lapatinib': None}

# %% [markdown]
# ### Generate new Dataframe

# %%
def get_smiles_from_name(drug_name):
    try:
        results = get_compounds(drug_name, 'name')
        if len(results) > 0:
            return results[0].canonical_smiles
    except:
        print(f"No match found for: {drug_name}")
        return None

def fetch_smiles(drug_list):
    smiles_dict = {}
    for drug in drug_list:
        smi = get_smiles_from_name(drug)
        smiles_dict[drug] = smi
        print(f"{drug}: {smi}")
        time.sleep(0.2)  # avoid rate-limiting
    return pd.DataFrame.from_dict(smiles_dict, orient="index", columns=["SMILES"])

# %%
# Clean names (remove concentration suffixes like ___133)
clean_drugs = list(set([d.split("___")[0] for d in gdsc_drugs]))

df_smiles = fetch_smiles(clean_drugs)
df_smiles.to_csv("gdsc_smiles.csv")
# Out:
# /scratch/tmp.51425295.rquiles/ipykernel_1491146/3131948375.py:5: PubChemPyDeprecationWarning: canonical_smiles is deprecated: Use connectivity_smiles instead
#   return results[0].canonical_smiles
# Fulvestrant: CC12CCC3C(C1CCC2O)C(CC4=C3C=CC(=C4)O)CCCCCCCCCS(=O)CCCC(C(F)(F)F)(F)F
# Paclitaxel: CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O
# Trametinib: CC1=C2C(=C(N(C1=O)C)NC3=C(C=C(C=C3)I)F)C(=O)N(C(=O)N2C4=CC=CC(=C4)NC(=O)C)C5CC5
# Irinotecan: CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=C1C=C(C=C5)OC(=O)N6CCC(CC6)N7CCCCC7

# %%
df_smiles = pd.read_csv("gdsc_smiles.csv", index=False)

# %% [markdown]
# ## Eliminate Cetuximab and Normalize Drug Names in Metadata

# %% [markdown]
# Elimiante Cetuximab:

# %%
metadata = pd.read_csv(os.path.join(base_dir, "combined_long_table.csv"))

# %%
metadata[metadata["drug"].str.split("___").str[0] == "Cetuximab"]
# Out:
#            species            sample_id       drug  response dataset
# 41           HOP62  95_001_111-lib_1681  Cetuximab       0.0     any
# 127           A172  95_002_071-lib_1681  Cetuximab       0.0     any
# 214       NCIH2030  95_003_116-lib_1681  Cetuximab       0.0     any
# 263        NCISNU1  95_004_100-lib_1681  Cetuximab       0.0     any
# 437           A498  95_005_118-lib_1681  Cetuximab       0.0     any
# ...            ...                  ...        ...       ...     ...
# 52469516      LOVO  96_185_048-lib_2608  Cetuximab       0.0     any
# 52469604     HOP62  96_186_088-lib_2608  Cetuximab       0.0     any
# 52469761  NCIH2030  96_187_181-lib_2608  Cetuximab       0.0     any
# 52469811     SHP77  96_191_125-lib_2608  Cetuximab       0.0     any
# 52469899      HT29  96_192_081-lib_2608  Cetuximab       0.0     any
#
# [574504 rows x 5 columns]

# %%
metadata = metadata[~(metadata["drug"].str.split("___").str[0] == "Cetuximab")]
metadata.to_csv(os.path.join(base_dir, "combined_long_table.csv", index=False))

# %% [markdown]
# Normalize drug names:

# %%
metadata = pd.read_csv(os.path.join(base_dir, "combined_long_table.csv"))

# %%
metadata[metadata["drug"].str.split("___").str[0] == "Cetuximab"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, species, sample_id, drug, response, dataset]
# Index: []

# %%
def norm_drug_gdsc(d):
    return d.split("___")[0]

metadata["drug"] = metadata["drug"].map(norm_drug_gdsc)

# %%
metadata
# Out:
#          species            sample_id         drug  response dataset
# 0          HOP62  95_001_111-lib_1681  Doxorubicin       1.0     any
# 1          HOP62  95_001_111-lib_1681  Doxorubicin       1.0     any
# 2          HOP62  95_001_111-lib_1681    Etoposide       1.0     any
# 3          HOP62  95_001_111-lib_1681  Gemcitabine       1.0     any
# 4          HOP62  95_001_111-lib_1681  Gemcitabine       1.0     any
# ...          ...                  ...          ...       ...     ...
# 51895436    HT29  96_192_081-lib_2608   Nelarabine       0.0     any
# 51895437    HT29  96_192_081-lib_2608  Vincristine       0.0     any
# 51895438    HT29  96_192_081-lib_2608   Venetoclax       0.0     any
# 51895439    HT29  96_192_081-lib_2608  Osimertinib       0.0     any
# 51895440    HT29  96_192_081-lib_2608  Vinorelbine       1.0     any
#
# [51895441 rows x 5 columns]

# %%
metadata.to_csv(os.path.join(base_dir, "combined_long_table.csv"), index=False)

# %%
import scanpy as sc
import pandas as pd
import numpy as np
from scipy import sparse
import re
import os

# %%
adata_path = "/cluster/scratch/rquiles/GDSC_control_counts.h5ad"
adata = sc.read_h5ad(adata_path)

# %%
np.isnan(adata.X.toarray()).sum(), np.isinf(adata.X.toarray()).sum()
# Out:
# (0, 0)

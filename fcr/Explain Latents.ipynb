# %% [markdown]
# # Explain FCR Latent Representation

# %% [markdown]
# The objective of this notebook is to explain the latent representations obtained by the FCR method, as well as the function of the encoder and the decoder.

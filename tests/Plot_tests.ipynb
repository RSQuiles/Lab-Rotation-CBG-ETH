# %%
# %load_ext autoreload
# %autoreload 2
    
from fcr.validation import plot_umaps

# %%
# model_dir = "/cluster/work/bewi/members/rquiles/experiments/parallel_test/1"
model_dir = "/cluster/work/bewi/members/rquiles/experiments/optimization/separate_emb_treat_emb"
plot_umaps(model_dir, show_figs=True)
# Out:
# Model path: /cluster/work/bewi/members/rquiles/experiments/optimization/separate_emb_treat_emb/saves/optimization_2025.10.27_12:18:43/model_seed=None_epoch=549.pt
# Reading AnnData...
# Performing automatic train-test split with 0.2 ratio.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 # model_dir = "/cluster/work/bewi/members/rquiles/experiments/parallel_test/1"
#       2 model_dir = "/cluster/work/bewi/members/rquiles/experiments/optimization/separate_emb_treat_emb"
# ----> 3 plot_umaps(model_dir, show_figs=True)
#
# File /cluster/work/bewi/members/rquiles/fcr/validation/view_results.py:201, in plot_umaps(model_dir, target_epoch, filter_dict, all_drugs, sample, show_figs)
#     181 """
#     182 Plot UMAPs for FCR latent representations.
#     183
#    (...)
#     197         {'cell_name': 'A375', 'dose': 10}  # Multiple conditions
# ...
